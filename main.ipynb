# %% [markdown]
# # Сlustering

# %%
import pandas as pd

# %%
df_factors = pd.read_csv('./data/Factors.csv')
df_factors.head()
# Out:
#    id_factors  id_year  id_country      GDP  Life_expectancy  Amount_unempl  \
# 0         1.0     28.0         1.0      NaN              NaN          11.18
# 1         2.0     27.0         1.0  512.013             63.1          11.16
# 2         3.0     26.0         1.0  556.007             62.7          11.13
# 3         4.0     25.0         1.0  614.223             62.5          11.14
# 4         5.0     24.0         1.0  624.315             62.4          11.19
#
#    Density  Schizophrenia  Bipolar_disorder  Eating_disorders  ...  \
# 0      NaN       0.166158          0.708089          0.107142  ...
# 1     53.1       0.166035          0.707686          0.105808  ...
# 2     51.8       0.165895          0.707275          0.104445  ...
# 3     50.2       0.165742          0.706876          0.103137  ...
# 4     48.4       0.165579          0.706471          0.101291  ...
#
#    PopFemale_50_64  PopMale_65_79  PopFemale_65_79  PopMale_80_94  \
# ...

# %% [markdown]
# # Prognostication
